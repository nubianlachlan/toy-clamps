# %%
import os
import math
import cadquery as cq
from ocp_vscode import show

# %%
from popsicle_connectors import make_one_way_connector

result = make_one_way_connector()
show(result)
# Out:
# c
# ...

# %%
from popsicle_connectors import make_2_way_connector

result = make_2_way_connector()
show(result)
# Out:
# c
# ...
